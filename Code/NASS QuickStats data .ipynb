# %% [markdown]
# # NASS QuickStats data
#
# <br> Glossary: [here](https://quickstats.nass.usda.gov/src/glossary.pdf)
#
# ### <B> This notebook explains step by step detailed process behind the cleaning and pre processing of the NASS QuickStatsdata.

# %% [markdown]
# # DATA CLEANSING AND PRE PROCESSING

# %%
#import packages

import csv
import numpy as np
import pandas as pd
from datetime import date 
from datetime import datetime
import time 
from pandas_profiling import ProfileReport

# %%
#get an overview of the dataset by limiting records by 20000

data = pd.read_csv("data/qs.crops_20200429.txt", nrows=20000, sep='\t')
data.head()
# Out:
#   SOURCE_DESC SECTOR_DESC    GROUP_DESC            COMMODITY_DESC  \
# 0      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 1      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 2      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 3      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 4      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
#
#               CLASS_DESC       PRODN_PRACTICE_DESC UTIL_PRACTICE_DESC  \
# 0  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 1  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 2  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 3  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 4  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
#
#   STATISTICCAT_DESC UNIT_DESC  \
# 0             SALES      POTS
# 1             SALES      POTS
# 2             SALES      POTS
# 3             SALES      POTS
# 4             SALES      POTS
#
#                                           SHORT_DESC  ... LOCATION_DESC  YEAR  \
# 0  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       ALABAMA  2009
# 1  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      ARKANSAS  2014
# 2  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...    CALIFORNIA  2009
# 3  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...    CALIFORNIA  2014
# 4  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      COLORADO  2014
#
#   FREQ_DESC  BEGIN_CODE  END_CODE REFERENCE_PERIOD_DESC WEEK_ENDING  \
# 0    ANNUAL           0         0                  YEAR         NaN
# 1    ANNUAL           0         0                  YEAR         NaN
# 2    ANNUAL           0         0                  YEAR         NaN
# 3    ANNUAL           0         0                  YEAR         NaN
# 4    ANNUAL           0         0                  YEAR         NaN
#
#              LOAD_TIME   VALUE  CV_%
# 0  2015-01-31 00:00:00     820   NaN
# 1  2015-01-31 00:00:00     (D)   (D)
# 2  2015-01-31 00:00:00  10,922   NaN
# 3  2015-01-31 00:00:00     885   7.4
# 4  2015-01-31 00:00:00     (D)   (D)
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Data Chunking

# %%
# step1.dividing data into chunks 
# step2. filtering out data before 1990

file_path = 'data/qs.crops_20200429.txt'
chunksize = 1000
df_chunks = []

for df in pd.read_csv(file_path, chunksize=chunksize, iterator=True, sep='\t',low_memory=False ):
    df_f = df.loc[(df['YEAR']>=1990)]
    df_chunks.append(df_f)
    #print(df_chunks)
master_df = pd.concat(df_chunks)
print(master_df.head())
# Out:
#   SOURCE_DESC SECTOR_DESC    GROUP_DESC            COMMODITY_DESC  \
# 0      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 1      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 2      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 3      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 4      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
#
#               CLASS_DESC       PRODN_PRACTICE_DESC UTIL_PRACTICE_DESC  \
# 0  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 1  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 2  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 3  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
# 4  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES       RETAIL, POTS
#
#   STATISTICCAT_DESC UNIT_DESC  \
# 0             SALES      POTS
# 1             SALES      POTS
# 2             SALES      POTS
# 3             SALES      POTS
# 4             SALES      POTS
#
#                                           SHORT_DESC  ... LOCATION_DESC  YEAR  \
# 0  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       ALABAMA  2009
# 1  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      ARKANSAS  2014
# 2  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...    CALIFORNIA  2009
# 3  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...    CALIFORNIA  2014
# 4  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      COLORADO  2014
#
#   FREQ_DESC  BEGIN_CODE  END_CODE REFERENCE_PERIOD_DESC WEEK_ENDING  \
# 0    ANNUAL           0         0                  YEAR         NaN
# 1    ANNUAL           0         0                  YEAR         NaN
# 2    ANNUAL           0         0                  YEAR         NaN
# 3    ANNUAL           0         0                  YEAR         NaN
# 4    ANNUAL           0         0                  YEAR         NaN
#
#              LOAD_TIME   VALUE  CV_%
# 0  2015-01-31 00:00:00     820   NaN
# 1  2015-01-31 00:00:00     (D)   (D)
# 2  2015-01-31 00:00:00  10,922   NaN
# 3  2015-01-31 00:00:00     885   7.4
# 4  2015-01-31 00:00:00     (D)   (D)
#
# [5 rows x 39 columns]

# %%
# get an overview of data commodity to filter out crops

master_df['COMMODITY_DESC'].unique()
# Out:
# array(['FLOWERING PLANTS, POTTED', 'BARLEY', 'BEANS', 'CANOLA', 'COFFEE',
#        'CORN', 'COTTON', 'FLAXSEED', 'HAY & HAYLAGE', 'HAY', 'HOPS',
#        'LENTILS', 'MAPLE SYRUP', 'MILLET', 'MUSTARD', 'OATS', 'PEANUTS',
#        'PEAS', 'POTATOES', 'RAPESEED', 'RICE', 'RYE', 'SAFFLOWER',
#        'SORGHUM', 'SOYBEANS', 'SUGARBEETS', 'SUNFLOWER', 'SWEET POTATOES',
#        'TARO', 'TOBACCO', 'WHEAT', 'ARTICHOKES', 'ASPARAGUS', 'BROCCOLI',
#        'BRUSSELS SPROUTS', 'CABBAGE', 'CAULIFLOWER', 'CELERY',
#        'SWEET CORN', 'PICKLES', 'GARLIC', 'GINGER ROOT', 'GREENS', 'OKRA',
#        'ONIONS', 'PEPPERS', 'PUMPKINS', 'RADISHES', 'SQUASH',
#        'STRAWBERRIES', 'APPLES', 'APRICOTS', 'BOYSENBERRIES',
#        'RASPBERRIES', 'CHERRIES', 'GRAPES', 'ALMONDS', 'PISTACHIOS',
#        'WALNUTS', 'PAPAYAS', 'PEACHES', 'GRAPEFRUIT', 'K-EARLY CITRUS',
#        'LEMONS', 'LIMES', 'ORANGES', 'TEMPLES', 'TANGELOS', 'TANGERINES',
#        'FEED GRAINS & HAY', 'CROPS, OTHER', 'FOOD GRAINS',
#        'FRUIT & TREE NUT TOTALS', 'OIL-BEARING CROPS',
#        'POTATOES & DRY BEANS', 'VEGETABLE TOTALS', 'MUSHROOMS', 'BANANAS',
#        'BLACKBERRIES', 'BLUEBERRIES', 'CANEBERRIES', 'CRANBERRIES',
#        'LOGANBERRIES', 'GUAVAS', 'MACADAMIAS', 'PECANS',
#        'BULBS & CORMS & RHIZOMES & TUBERS', 'BERRY TOTALS',
#        'BEDDING PLANTS, HERBACEOUS PERENNIAL', 'HAYLAGE', 'HAZELNUTS',
#        'BEETS', 'EGGPLANT', 'ESCAROLE & ENDIVE', 'MELONS', 'AVOCADOS',
#        'DATES', 'FIGS', 'NON-CITRUS FRUIT & TREE NUTS TOTALS',
#        'KIWIFRUIT', 'NECTARINES', 'OLIVES', 'PEARS', 'PINEAPPLES',
#        'PLUMS & PRUNES', 'PLUMS', 'PRUNES', 'LETTUCE', 'LEGUMES',
#        'PROPAGATIVE MATERIAL', 'CROP TOTALS', 'AMARANTH', 'BUCKWHEAT',
#        'CRAMBE', 'FIELD CROPS, OTHER', 'EMMER & SPELT', 'GRAIN', 'GUAR',
#        'JOJOBA', 'LOTUS ROOT', 'SESAME', 'SUGARCANE', 'SWEET RICE',
#        'TRITICALE', 'WILD RICE', 'FRUIT & TREE NUTS, OTHER',
#        'CITRUS TOTALS', 'CITRUS, OTHER', 'KUMQUATS', 'TRANSPLANTS',
#        'SHORT TERM WOODY CROPS', 'CUT CULTIVATED GREENS',
#        'DECIDUOUS SHRUBS', 'BERRIES, OTHER', 'CUT CHRISTMAS TREES',
#        'CURRANTS', 'MANGOES', 'NON-CITRUS TOTALS', 'NON-CITRUS, OTHER',
#        'PASSION FRUIT', 'PERSIMMONS', 'POMEGRANATES', 'CHESTNUTS',
#        'TREE NUT TOTALS', 'TREE NUTS, OTHER', 'HORTICULTURE TOTALS',
#        'CUT CHRISTMAS TREES & SHORT TERM WOODY CROPS',
#        'BEDDING PLANTS, ANNUAL', 'BEDDING PLANT TOTALS',
#        'CUT FLOWERS & CUT CULTIVATED GREENS', 'FLORICULTURE TOTALS',
#        'FLORICULTURE, OTHER', 'FRUIT TOTALS', 'MUSHROOM SPAWN',
#        'TOMATOES', 'NURSERY, OTHER', 'NURSERY TOTALS', 'AQUATIC PLANTS',
#        'FLOWER SEEDS', 'SOD', 'VEGETABLE SEEDS', 'CARROTS', 'CHICORY',
#        'CUCUMBERS', 'DAIKON', 'GINSENG', 'HORSERADISH', 'PARSLEY',
#        'PIMIENTOS', 'RHUBARB', 'SPINACH', 'DECIDUOUS SHADE TREES',
#        'TURNIPS', 'VEGETABLES, MIXED', 'VEGETABLES, OTHER', 'WATERCRESS',
#        'POPCORN', 'OIL', 'MINT', 'CAKE & MEAL', 'CRUDE PINE GUM',
#        'GOOSEBERRIES', 'CUT FLOWERS', 'GRAIN STORAGE CAPACITY', 'HERBS',
#        'FIELD CROP TOTALS', 'FRUIT, OTHER', 'MILLFEED',
#        'FRUIT & NUT PLANTS', 'FLOUR', 'PEAS & CARROTS', 'DILL',
#        'ALCOHOL COPRODUCTS', 'GRASSES', 'GRASSES & LEGUMES TOTALS',
#        'GRASSES & LEGUMES, OTHER', 'PASTURELAND', 'ORCHARDS',
#        'SMALL GRAINS', 'PEAS & LENTILS', 'HORTICULTURE, OTHER',
#        'FOOD CROP TOTALS', 'FOLIAGE PLANTS', 'FOOD CROP, OTHER',
#        'WOODY ORNAMENTALS & VINES, OTHER', 'PALMS', 'ORNAMENTAL GRASSES',
#        'EVERGREENS, CONIFEROUS', 'EVERGREENS, BROADLEAF', 'CAMELINA',
#        'DECIDUOUS FLOWERING TREES', 'BAREROOT HERBACEOUS PERENNIALS',
#        'PLUM-APRICOT HYBRIDS', 'MISCANTHUS', 'SWITCHGRASS',
#        'PACKING FACILITY', 'FEED GRAINS', 'FIELDWORK', 'SOIL', 'SNOW',
#        'CACTI & SUCCULENTS', 'CHERIMOYAS', 'ARONIA BERRIES',
#        'ELDERBERRIES', 'CHICKPEAS', 'COLD STORAGE CAPACITY'], dtype=object)

# %% [markdown]
# ### Data Profiling
#
# Data profiling is the process of reviewing source data, understanding structure, content and interrelationships, and identifying potential for data projects

# %%
#filtering out the required crop type

crops = ['WHEAT', 'RICE','COTTON','CORN','SOYBEANS']
master_df.COMMODITY_DESC.isin(crops)
filter_crops= master_df[master_df.COMMODITY_DESC.isin(crops)]
filter_crops.head()
# Out:
#        SOURCE_DESC SECTOR_DESC   GROUP_DESC COMMODITY_DESC   CLASS_DESC  \
# 706737      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706738      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706741      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706742      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706743      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
#
#        PRODN_PRACTICE_DESC         UTIL_PRACTICE_DESC STATISTICCAT_DESC  \
# 706737           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706738           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706741           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706742           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706743           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
#
#        UNIT_DESC                       SHORT_DESC  ...  \
# 706737     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706738     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706741     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706742     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706743     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
#
#                        LOCATION_DESC  YEAR FREQ_DESC  BEGIN_CODE  END_CODE  \
# 706737  COLORADO, NORTHEAST, BOULDER  2002    ANNUAL           0         0
# 706738  COLORADO, NORTHEAST, BOULDER  1997    ANNUAL           0         0
# 706741  COLORADO, NORTHEAST, BOULDER  2010    ANNUAL           0         0
# 706742  COLORADO, NORTHEAST, BOULDER  1995    ANNUAL           0         0
# 706743  COLORADO, NORTHEAST, BOULDER  1996    ANNUAL           0         0
#
#        REFERENCE_PERIOD_DESC WEEK_ENDING            LOAD_TIME  VALUE  CV_%
# 706737                  YEAR         NaN  2012-01-01 00:00:00  3,500   NaN
# 706738                  YEAR         NaN  2012-01-01 00:00:00  6,800   NaN
# 706741                  YEAR         NaN  2015-06-03 15:08:31  3,000   NaN
# 706742                  YEAR         NaN  2012-01-01 00:00:00  7,000   NaN
# 706743                  YEAR         NaN  2012-01-01 00:00:00  7,000   NaN
#
# [5 rows x 39 columns]

# %%
filter_crops.shape
# Out:
# (3833173, 39)

# %%
filter_crops.columns
# Out:
# Index(['SOURCE_DESC', 'SECTOR_DESC', 'GROUP_DESC', 'COMMODITY_DESC',
#        'CLASS_DESC', 'PRODN_PRACTICE_DESC', 'UTIL_PRACTICE_DESC',
#        'STATISTICCAT_DESC', 'UNIT_DESC', 'SHORT_DESC', 'DOMAIN_DESC',
#        'DOMAINCAT_DESC', 'AGG_LEVEL_DESC', 'STATE_ANSI', 'STATE_FIPS_CODE',
#        'STATE_ALPHA', 'STATE_NAME', 'ASD_CODE', 'ASD_DESC', 'COUNTY_ANSI',
#        'COUNTY_CODE', 'COUNTY_NAME', 'REGION_DESC', 'ZIP_5', 'WATERSHED_CODE',
#        'WATERSHED_DESC', 'CONGR_DISTRICT_CODE', 'COUNTRY_CODE', 'COUNTRY_NAME',
#        'LOCATION_DESC', 'YEAR', 'FREQ_DESC', 'BEGIN_CODE', 'END_CODE',
#        'REFERENCE_PERIOD_DESC', 'WEEK_ENDING', 'LOAD_TIME', 'VALUE', 'CV_%'],
#       dtype='object')

# %%
filter_crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3833173 entries, 706737 to 19112390
# Data columns (total 39 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   SOURCE_DESC            object
#  1   SECTOR_DESC            object
#  2   GROUP_DESC             object
#  3   COMMODITY_DESC         object
#  4   CLASS_DESC             object
#  5   PRODN_PRACTICE_DESC    object
#  6   UTIL_PRACTICE_DESC     object
#  7   STATISTICCAT_DESC      object
#  8   UNIT_DESC              object
#  9   SHORT_DESC             object
#  10  DOMAIN_DESC            object
#  11  DOMAINCAT_DESC         object
#  12  AGG_LEVEL_DESC         object
#  13  STATE_ANSI             float64
#  14  STATE_FIPS_CODE        int64
#  15  STATE_ALPHA            object
#  16  STATE_NAME             object
#  17  ASD_CODE               float64
#  18  ASD_DESC               object
#  19  COUNTY_ANSI            float64
#  20  COUNTY_CODE            float64
#  21  COUNTY_NAME            object
#  22  REGION_DESC            object
#  23  ZIP_5                  float64
#  24  WATERSHED_CODE         int64
#  25  WATERSHED_DESC         object
#  26  CONGR_DISTRICT_CODE    float64
#  27  COUNTRY_CODE           int64
#  28  COUNTRY_NAME           object
#  29  LOCATION_DESC          object
#  30  YEAR                   int64
#  31  FREQ_DESC              object
#  32  BEGIN_CODE             int64
#  33  END_CODE               int64
#  34  REFERENCE_PERIOD_DESC  object
#  35  WEEK_ENDING            object
#  36  LOAD_TIME              object
#  37  VALUE                  object
#  38  CV_%                   object
# dtypes: float64(6), int64(6), object(27)
# memory usage: 1.1+ GB

# %%
filter_crops.describe()
# Out:
#          STATE_ANSI  STATE_FIPS_CODE      ASD_CODE   COUNTY_ANSI  \
# count  3.739526e+06     3.833173e+06  2.218381e+06  1.840741e+06
# mean   3.051904e+01     3.192874e+01  4.930453e+01  9.726272e+01
# std    1.441217e+01     1.746798e+01  2.622476e+01  8.681253e+01
# min    1.000000e+00     0.000000e+00  1.000000e+01  1.000000e+00
# 25%    2.000000e+01     2.000000e+01  3.000000e+01  3.700000e+01
# 50%    3.000000e+01     3.000000e+01  5.000000e+01  7.900000e+01
# 75%    4.200000e+01     4.500000e+01  7.000000e+01  1.310000e+02
# max    5.600000e+01     9.900000e+01  9.800000e+01  8.100000e+02
#
#         COUNTY_CODE          ZIP_5  WATERSHED_CODE  CONGR_DISTRICT_CODE  \
# count  1.980210e+06  300614.000000    3.833173e+06                  0.0
# mean   1.606932e+02   51463.057156    2.001533e+04                  NaN
# std    2.451974e+02   19956.443565    4.878126e+05                  NaN
# min    1.000000e+00    1002.000000    0.000000e+00                  NaN
# 25%    4.100000e+01   38341.000000    0.000000e+00                  NaN
# 50%    8.500000e+01   53523.000000    0.000000e+00                  NaN
# 75%    1.490000e+02   65330.000000    0.000000e+00                  NaN
# max    9.990000e+02   99999.000000    2.007000e+07                  NaN
#
#        COUNTRY_CODE          YEAR    BEGIN_CODE      END_CODE
# count     3833173.0  3.833173e+06  3.833173e+06  3.833173e+06
# mean         9000.0  2.005906e+03  6.551220e+00  6.551396e+00
# std             0.0  8.926106e+00  1.285902e+01  1.285903e+01
# min          9000.0  1.990000e+03  0.000000e+00  0.000000e+00
# 25%          9000.0  1.998000e+03  0.000000e+00  0.000000e+00
# 50%          9000.0  2.007000e+03  0.000000e+00  0.000000e+00
# 75%          9000.0  2.014000e+03  0.000000e+00  0.000000e+00
# max          9000.0  2.020000e+03  5.300000e+01  5.300000e+01

# %%
# describing the categortical variable

filter_crops.COUNTY_NAME.describe()
# Out:
# count                       1969586
# unique                         1749
# top       OTHER (COMBINED) COUNTIES
# freq                         128813
# Name: COUNTY_NAME, dtype: object

# %%
# list of columns

list_cols=[]
list_cols=list(filter_crops)
list_cols
# Out:
# ['SOURCE_DESC',
#  'SECTOR_DESC',
#  'GROUP_DESC',
#  'COMMODITY_DESC',
#  'CLASS_DESC',
#  'PRODN_PRACTICE_DESC',
#  'UTIL_PRACTICE_DESC',
#  'STATISTICCAT_DESC',
#  'UNIT_DESC',
#  'SHORT_DESC',
#  'DOMAIN_DESC',
#  'DOMAINCAT_DESC',
#  'AGG_LEVEL_DESC',
#  'STATE_ANSI',
#  'STATE_FIPS_CODE',
#  'STATE_ALPHA',
#  'STATE_NAME',
#  'ASD_CODE',
#  'ASD_DESC',
#  'COUNTY_ANSI',
#  'COUNTY_CODE',
#  'COUNTY_NAME',
#  'REGION_DESC',
#  'ZIP_5',
#  'WATERSHED_CODE',
#  'WATERSHED_DESC',
#  'CONGR_DISTRICT_CODE',
#  'COUNTRY_CODE',
#  'COUNTRY_NAME',
#  'LOCATION_DESC',
#  'YEAR',
#  'FREQ_DESC',
#  'BEGIN_CODE',
#  'END_CODE',
#  'REFERENCE_PERIOD_DESC',
#  'WEEK_ENDING',
#  'LOAD_TIME',
#  'VALUE',
#  'CV_%']

# %%
#check for unique values of all the columns, it helps filter out the values of columns

for cols in list_cols:
    print( cols,':',  filter_crops[cols].unique())
# Out:
# SOURCE_DESC : ['SURVEY' 'CENSUS']
# SECTOR_DESC : ['CROPS']
# GROUP_DESC : ['FIELD CROPS']
# COMMODITY_DESC : ['CORN' 'COTTON' 'RICE' 'SOYBEANS' 'WHEAT']
# CLASS_DESC : ['ALL CLASSES' 'PIMA' 'COTTONSEED' 'UPLAND' 'LONG GRAIN' 'MEDIUM GRAIN'
#  'SHORT GRAIN' 'SPRING, DURUM' 'SPRING, (EXCL DURUM)' 'WINTER' 'RED, HARD'
#  'SPRING, RED, HARD' 'WHITE' 'WINTER, RED, HARD' 'WINTER, RED, SOFT'
#  'MEDIUM-SHORT GRAIN' 'WINTER, WHITE, HARD' 'SPRING, WHITE, SOFT'
#  'SPRING, WHITE, HARD' 'WINTER, WHITE, SOFT' 'SPRING, WHITE'
#  'WINTER, WHITE' 'ROUGH, LONG GRAIN' 'ROUGH, MEDIUM GRAIN'
#  'ROUGH, SHORT GRAIN' 'ROUGH' 'MILLED, BROKEN, BREWERS' 'MILLED, BROKEN'
#  'MILLED' 'MILLED, WHOLE' 'MILLED, BROKEN, SCREENINGS'
#  'MILLED, BROKEN, SECOND HEADS' 'MILLED, WHOLE, LONG GRAIN'
#  'MILLED, WHOLE, MEDIUM GRAIN' 'MILLED, WHOLE, SHORT GRAIN'
#  'LINT TO LINT & SEED' '(EXCL DURUM)' '(EXCL UPLAND)'
#  'TRADITIONAL OR INDIAN']
# PRODN_PRACTICE_DESC : ['IRRIGATED' 'NON-IRRIGATED' 'ALL PRODUCTION PRACTICES'
#  'FOLLOWING ANOTHER CROP (DOUBLE CROPPED)' 'NOT FOLLOWING ANOTHER CROP'
#  'NON-IRRIGATED, FOLLOWING SUMMER FALLOW' 'NON-IRRIGATED, CONTINUOUS CROP'
#  'BIOTECH, BT' 'BIOTECH, HERBICIDE RESISTANT' 'BIOTECH, STACKED GENE'
#  'BIOTECH' 'IRRIGATED, ENTIRE CROP' 'IRRIGATED, NONE OF CROP'
#  'IRRIGATED, PART OF CROP' 'IRRIGATED, PART OF CROP, IRRIGATED PORTION'
#  'ORGANIC' 'IRRIGATED, PART OF CROP, NON-IRRIGATED PORTION'
#  '1 DAY AFTER CROP PRODUCTION REPORT' '1 DAY AFTER GRAIN STOCKS REPORT'
#  'PRIOR TO CLOSING THE DAY OF CROP PRODUCTION REPORT'
#  'PRIOR TO CLOSING THE DAY OF GRAIN STOCKS REPORT'
#  '1 WEEK AFTER CROP PRODUCTION REPORT' '1 WEEK AFTER GRAIN STOCKS REPORT']
# UTIL_PRACTICE_DESC : ['ALL UTILIZATION PRACTICES' 'SILAGE' 'GRAIN' 'ON FARM'
#  'FOR FLOUR & SEMOLINA' 'LINT & SEED' 'OFF FARM' 'OFF FARM, GRAIN'
#  'OFF FARM, MILLS & ATTACHED WAREHOUSES' 'OFF FARM, PORTS OR TRANSIT'
#  'OFF FARM, UNATTACHED WAREHOUSES' 'ON FARM, GRAIN' 'FOR ALCOHOL'
#  'FOR OTHER PRODUCTS (EXCL ALCOHOL)' 'FOR ALCOHOL & OTHER PRODUCTS'
#  'FOR FLOUR' 'FOR FUEL ALCOHOL' 'AT HARVEST, GRAIN' 'AT HARVEST' 'INSECT'
#  'WIND' 'WINTERKILL' 'MANMADE FIBER, POLYESTER STAPLE'
#  'MANMADE FIBER, RAYON & ACETATE STAPLE' 'MANMADE FIBER, OTHER'
#  'FOR INDUSTRIAL ALCOHOL' 'FOR BEVERAGE ALCOHOL' 'FREEZE'
#  'GRAIN, DENT STAGE' 'GRAIN, MATURE STAGE']
# STATISTICCAT_DESC : ['AREA PLANTED' 'GINNED BALES' 'AREA HARVESTED' 'PRODUCTION'
#  'PRICE RECEIVED' 'PRICE RECEIVED, ADJUSTED BASE' 'PRICE RECEIVED, PARITY'
#  'SALES' 'YIELD' 'AREA PLANTED, NET'
#  'INDEX FOR PRICE RECEIVED, 1910 - 1914'
#  'INDEX FOR PRICE RECEIVED, 1990 - 1992' 'STOCKS' 'BOLL COUNT'
#  'SALES IN CONVENTIONAL MARKETS' 'SALES IN ORGANIC MARKETS'
#  'RELATIVE WEIGHT' 'CRUSHED' 'EAR COUNT' 'POD COUNT' 'USAGE' 'RATIO'
#  'WATER APPLIED' 'INDEX FOR PRICE RECEIVED, 2011' 'CONDITION'
#  'PROGRESS, 5 YEAR AVG' 'PROGRESS' 'MOISTURE' 'HEIGHT, AVG' 'INFESTATION'
#  'DAMAGE' 'MOISTURE, PREVIOUS YEAR' 'PROGRESS, PREVIOUS YEAR'
#  'CONDITION, PREVIOUS YEAR' 'HEIGHT, AVG, PREVIOUS YEAR' 'SAMPLES'
#  'ACTIVE GINS' 'DAMAGE, PREVIOUS YEAR' 'MOISTURE, 5 YEAR AVG'
#  'CONDITION, 5 YEAR AVG' 'HEIGHT, AVG, 5 YEAR AVG' 'DISAPPEARANCE'
#  'DAMAGE, 5 YEAR AVG' 'HARVEST LOSS' 'PLANT POPULATION' 'ROW WIDTH'
#  'SEED FOR PLANTING' 'OTHER SALE' 'MILL SALE' 'AREA FLOODED'
#  'PROCESSED IN LAB' 'PRICE RECEIVED AFTER REPORT'
#  'PRICE REACTION, DECREASE' 'PRICE REACTION, INCREASE'
#  'PRICE REACTION, NO CHANGE' 'PRICE REACTION'
#  'PRICE RECEIVED PRIOR TO CLOSING' 'HEAD COUNT']
# UNIT_DESC : ['ACRES' 'RUNNING BALES' '480 LB BALES' 'PCT OF PARITY' '$ / LB' 'TONS'
#  'PCT OF MKTG YEAR' 'CWT' 'BU' 'BU / NET PLANTED ACRE' 'BU / ACRE'
#  'BU / PLANTED ACRE' 'INDEX' 'PCT BY TYPE' '$ / BU' '$' '$ / TON'
#  '$ / CWT' 'LB / ACRE' 'LB / NET PLANTED ACRE' 'OPERATIONS' 'BALES'
#  'BALES / ACRE' 'CWT / ACRE' 'BOLLS / 40 FEET OF ROW'
#  'PCT OF COMMODITY TOTALS' 'EARS / ACRE' 'PODS / 18 SQ FT' 'LB / LB'
#  'TONS / ACRE' 'PCT OF OPERATIONS BY METHOD' 'PCT BY METHOD'
#  'ACRE FEET / ACRE' 'PCT OF FARM SALES' 'PCT OF FARM OPERATIONS'
#  'PCT EXCELLENT' 'PCT FAIR' 'PCT GOOD' 'PCT POOR' 'PCT VERY POOR'
#  'PCT DENTED' 'PCT EMERGED' 'PCT HARVESTED' 'PCT MATURE' 'PCT PLANTED'
#  'PCT SILKING' 'PCT HEADED' 'PCT BLOOMING' 'PCT DROPPING LEAVES'
#  'PCT SETTING PODS' 'PCT' 'INCHES' 'PCT DOUGH' 'PCT MILK'
#  'PCT SEEDBED PREPARED' 'PCT BOLLS OPENING' 'PCT DEFOLIATED'
#  'PCT SETTING BOLLS' 'PCT SQUARING' 'PCT COLORING' 'PCT BOOTED'
#  'PCT JOINTING' 'PCT LIGHT' 'PCT MODERATE' 'PCT NONE' 'PCT SEVERE'
#  'PCT BREAKING DORMANCY' 'PCT PASTURED' 'PCT BY SIZE GROUP' 'NUMBER' 'LB'
#  'LB, NET TRADING WEIGHT BASIS' 'PLANTS / ACRE' 'INCHES / ROW'
#  'LB / BALE, AVG' 'PCT OF PLANTED' 'PCT FULLY PODDED' 'CENTS / BU'
#  'POINTS / LB' 'HEAD / SQ FT' 'REACTIONS SINCE 1987'
#  'REACTIONS SINCE 1984' 'REACTIONS SINCE 1985' 'REACTIONS SINCE 1989'
#  'STALKS / ACRE']
# SHORT_DESC : ['CORN, IRRIGATED - ACRES PLANTED' 'CORN, NON-IRRIGATED - ACRES PLANTED'
#  'COTTON - GINNED BALES, MEASURED IN RUNNING BALES' ...
#  'CORN, TRADITIONAL OR INDIAN - PRODUCTION, MEASURED IN LB'
#  'CORN, TRADITIONAL OR INDIAN, IRRIGATED - OPERATIONS WITH AREA HARVESTED'
#  'CORN, TRADITIONAL OR INDIAN, IRRIGATED - ACRES HARVESTED']
# DOMAIN_DESC : ['TOTAL' 'AREA HARVESTED' 'ORGANIC STATUS' 'SALES' 'TYPE OF OPERATION'
#  'IRRIGATION METHOD, PRIMARY' 'WATER SOURCE'
#  'NAICS CLASSIFICATION AND AREA HARVESTED'
#  'ECONOMIC CLASS AND AREA HARVESTED' 'AREA OPERATED AND AREA HARVESTED'
#  'FARM SALES AND AREA HARVESTED' 'IRRIGATION STATUS'
#  'AREA IRRIGATED, HARVESTED' 'CONCENTRATION' 'FARM SALES'
#  'FARM SALES AND SALES' 'AREA OPERATED' 'ECONOMIC CLASS'
#  'NAICS CLASSIFICATION' 'AREA OPERATED AND SALES'
#  'ECONOMIC CLASS AND SALES' 'NAICS CLASSIFICATION AND SALES' 'ROW WIDTH'
#  'PLANT POPULATION' 'BALES GINNED']
# DOMAINCAT_DESC : ['NOT SPECIFIED' 'AREA HARVESTED: (1.0 TO 14.9 ACRES)'
#  'AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA HARVESTED: (1,000 OR MORE ACRES)'
#  'AREA HARVESTED: (1,000 TO 1,999 ACRES)'
#  'AREA HARVESTED: (15.0 TO 24.9 ACRES)'
#  'AREA HARVESTED: (2,000 TO 2,999 ACRES)'
#  'AREA HARVESTED: (25.0 TO 49.9 ACRES)'
#  'AREA HARVESTED: (250 TO 499 ACRES)'
#  'AREA HARVESTED: (3,000 TO 4,999 ACRES)'
#  'AREA HARVESTED: (50.0 TO 99.9 ACRES)'
#  'AREA HARVESTED: (500 TO 999 ACRES)'
#  'AREA HARVESTED: (5,000 OR MORE ACRES)'
#  'AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'AREA HARVESTED: (500 OR MORE ACRES)'
#  'ORGANIC STATUS: (NOP USDA CERTIFIED & EXEMPT)'
#  'ORGANIC STATUS: (NOP USDA EXEMPT)' 'SALES: (50,000 OR MORE $)'
#  'AREA HARVESTED: (1.0 TO 49.9 ACRES)' 'AREA HARVESTED: (50 TO 249 ACRES)'
#  'AREA HARVESTED: (250 OR MORE ACRES)' 'TYPE OF OPERATION: (PRIVATE)'
#  'ORGANIC STATUS: (NOP USDA CERTIFIED)'
#  'TYPE OF OPERATION: (WHEAT OR RYE FLOUR MILL)'
#  'TYPE OF OPERATION: (WET MILL PLANT)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, CONTROLLED FLOODING (BETWEEN BORDERS OR WITHIN ROWS), POLY OR LAY FLAT OR ABOVE GROUND PIPE)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, DOWN ROWS OR FURROWS, POLY OR LAY FLAT OR ABOVE OR UNDERGROUND PIPE)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, OTHER)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, CENTER PIVOT & LINEAR MOVE TOWER, GE 60 PSI)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, CENTER PIVOT & LINEAR MOVE TOWER, 30 TO 59 PSI)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, CENTER PIVOT & LINEAR MOVE TOWER, 15 TO 29 PSI)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, CENTER PIVOT & LINEAR MOVE TOWER, LT 15 PSI)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, OTHER)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, UNCONTROLLED FLOODING)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, CONTROLLED FLOODING (BETWEEN BORDERS OR WITHIN ROWS), UNDERGROUND PIPE)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, CONTROLLED FLOODING (BETWEEN BORDERS OR WITHIN ROWS), UNLINED DITCHES)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, CONTROLLED FLOODING (BETWEEN BORDERS OR WITHIN ROWS), LINED DITCHES)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, DOWN ROWS OR FURROWS, UNLINED DITCHES)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY, DOWN ROWS OR FURROWS, LINED DITCHES)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, HAND MOVE)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, BIG GUN OR TRAVELER)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, SIDE ROLL OR WHEEL LINE)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER, SOLID SET OR PERMANENT)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, LOW FLOW (DRIP OR MICRO SPRINKLER))'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE, SPRINKLER)'
#  'IRRIGATION METHOD, PRIMARY: (GRAVITY)'
#  'IRRIGATION METHOD, PRIMARY: (PRESSURE)' 'WATER SOURCE: (OFF FARM)'
#  'WATER SOURCE: (ON FARM SURFACE)' 'WATER SOURCE: (GROUND)'
#  'NAICS CLASSIFICATION: (1124) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1125 & 1129) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1124) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1114) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'ECONOMIC CLASS: (2,500 TO 4,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (1,000 TO 2,499 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (5,000 TO 9,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (10,000 TO 24,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (LESS THAN 1,000 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (1,000 TO 2,499 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (2,500 TO 4,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (1,000 TO 2,499 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (LESS THAN 1,000 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (180 TO 219 ACRES) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (1,000 TO 2,499 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'FARM SALES: (5,000 TO 9,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'FARM SALES: (50,000 TO 99,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'FARM SALES: (LESS THAN 1,000 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (25,000 TO 49,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (5,000 TO 9,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'IRRIGATION STATUS: (ANY ON OPERATION)'
#  'AREA IRRIGATED, HARVESTED: (250 TO 449 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (1.0 TO 99.9 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (1.0 TO 49.9 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (250 OR MORE ACRES)'
#  'AREA IRRIGATED, HARVESTED: (500 OR MORE ACRES)'
#  'AREA IRRIGATED, HARVESTED: (500 TO 999 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (1.0 TO 24.9 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (50.0 TO 99.9 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (250 TO 499 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (1,000 OR MORE ACRES)'
#  'AREA IRRIGATED, HARVESTED: (25.0 TO 49.9 ACRES)'
#  'AREA IRRIGATED, HARVESTED: (100 TO 249 ACRES)'
#  'TYPE OF OPERATION: (DRY MILL PLANT)'
#  'CONCENTRATION: (TOP 10 PCT OF OPERATIONS ON FARM SALES BASIS)'
#  'CONCENTRATION: (TOP 25 PCT OF OPERATIONS ON FARM SALES BASIS)'
#  'CONCENTRATION: (TOP 50 PCT OF OPERATIONS ON FARM SALES BASIS)'
#  'CONCENTRATION: (TOP 75 PCT OF OPERATIONS ON FARM SALES BASIS)'
#  'FARM SALES: (1,000,000 OR MORE $)' 'FARM SALES: (500,000 TO 999,999 $)'
#  'FARM SALES: (250,000 TO 499,999 $)' 'FARM SALES: (100,000 TO 249,999 $)'
#  'FARM SALES: (50,000 TO 99,999 $)' 'FARM SALES: (25,000 TO 49,999 $)'
#  'FARM SALES: (10,000 TO 24,999 $)' 'FARM SALES: (5,000 TO 9,999 $)'
#  'FARM SALES: (2,500 TO 4,999 $)' 'FARM SALES: (1,000 TO 2,499 $)'
#  'FARM SALES: (LESS THAN 1,000 $)'
#  'FARM SALES: (1,000,000 OR MORE $) AND SALES: (50,000 OR MORE $)'
#  'FARM SALES: (500,000 TO 999,999 $) AND SALES: (50,000 OR MORE $)'
#  'FARM SALES: (250,000 TO 499,999 $) AND SALES: (50,000 OR MORE $)'
#  'FARM SALES: (100,000 TO 249,999 $) AND SALES: (50,000 OR MORE $)'
#  'FARM SALES: (50,000 TO 99,999 $) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (1.0 TO 9.9 ACRES)' 'AREA OPERATED: (10.0 TO 49.9 ACRES)'
#  'AREA OPERATED: (50.0 TO 69.9 ACRES)'
#  'AREA OPERATED: (70.0 TO 99.9 ACRES)' 'AREA OPERATED: (100 TO 139 ACRES)'
#  'AREA OPERATED: (140 TO 179 ACRES)' 'AREA OPERATED: (180 TO 219 ACRES)'
#  'AREA OPERATED: (220 TO 259 ACRES)' 'AREA OPERATED: (260 TO 499 ACRES)'
#  'AREA OPERATED: (500 TO 999 ACRES)'
#  'AREA OPERATED: (1,000 TO 1,999 ACRES)'
#  'AREA OPERATED: (2,000 OR MORE ACRES)'
#  'ECONOMIC CLASS: (1,000,000 OR MORE $)'
#  'ECONOMIC CLASS: (500,000 TO 999,999 $)'
#  'ECONOMIC CLASS: (250,000 TO 499,999 $)'
#  'ECONOMIC CLASS: (100,000 TO 249,999 $)'
#  'ECONOMIC CLASS: (50,000 TO 99,999 $)'
#  'ECONOMIC CLASS: (25,000 TO 49,999 $)'
#  'ECONOMIC CLASS: (10,000 TO 24,999 $)'
#  'ECONOMIC CLASS: (5,000 TO 9,999 $)' 'ECONOMIC CLASS: (2,500 TO 4,999 $)'
#  'ECONOMIC CLASS: (1,000 TO 2,499 $)'
#  'ECONOMIC CLASS: (LESS THAN 1,000 $)' 'NAICS CLASSIFICATION: (1111)'
#  'NAICS CLASSIFICATION: (1112)' 'NAICS CLASSIFICATION: (1113)'
#  'NAICS CLASSIFICATION: (1114)' 'NAICS CLASSIFICATION: (1119)'
#  'NAICS CLASSIFICATION: (11191)' 'NAICS CLASSIFICATION: (11192)'
#  'NAICS CLASSIFICATION: (11193 & 11194 & 11199)'
#  'NAICS CLASSIFICATION: (112111)' 'NAICS CLASSIFICATION: (112112)'
#  'NAICS CLASSIFICATION: (11212)' 'NAICS CLASSIFICATION: (1122)'
#  'NAICS CLASSIFICATION: (1123)' 'NAICS CLASSIFICATION: (1124)'
#  'NAICS CLASSIFICATION: (1125 & 1129)'
#  'AREA OPERATED: (10.0 TO 49.9 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (50.0 TO 69.9 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (70.0 TO 99.9 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (100 TO 139 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (140 TO 179 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (180 TO 219 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (220 TO 259 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (260 TO 499 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (500 TO 999 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES: (50,000 OR MORE $)'
#  'AREA OPERATED: (2,000 OR MORE ACRES) AND SALES: (50,000 OR MORE $)'
#  'ECONOMIC CLASS: (1,000,000 OR MORE $) AND SALES: (50,000 OR MORE $)'
#  'ECONOMIC CLASS: (500,000 TO 999,999 $) AND SALES: (50,000 OR MORE $)'
#  'ECONOMIC CLASS: (250,000 TO 499,999 $) AND SALES: (50,000 OR MORE $)'
#  'ECONOMIC CLASS: (100,000 TO 249,999 $) AND SALES: (50,000 OR MORE $)'
#  'ECONOMIC CLASS: (50,000 TO 99,999 $) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1111) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1112) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1113) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1114) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1119) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (11191) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (11192) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (11193 & 11194 & 11199) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (112111) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (112112) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (11212) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1122) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1123) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1124) AND SALES: (50,000 OR MORE $)'
#  'NAICS CLASSIFICATION: (1125 & 1129) AND SALES: (50,000 OR MORE $)'
#  'FARM SALES: (1,000,000 OR MORE $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (500,000 TO 999,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (250,000 TO 499,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (100,000 TO 249,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (50,000 TO 99,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (25,000 TO 49,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (10,000 TO 24,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (5,000 TO 9,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (2,500 TO 4,999 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (1,000 TO 2,499 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (LESS THAN 1,000 $) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)'
#  'FARM SALES: (1,000,000 OR MORE $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (500,000 TO 999,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (250,000 TO 499,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (100,000 TO 249,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (50,000 TO 99,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (25,000 TO 49,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (10,000 TO 24,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (2,500 TO 4,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (1,000 TO 2,499 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (LESS THAN 1,000 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'FARM SALES: (1,000,000 OR MORE $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (500,000 TO 999,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (250,000 TO 499,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (100,000 TO 249,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (50,000 TO 99,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (25,000 TO 49,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (10,000 TO 24,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (5,000 TO 9,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (2,500 TO 4,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (1,000 TO 2,499 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (LESS THAN 1,000 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'FARM SALES: (1,000,000 OR MORE $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (500,000 TO 999,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (250,000 TO 499,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (100,000 TO 249,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (50,000 TO 99,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (10,000 TO 24,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'FARM SALES: (5,000 TO 9,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  
AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'ECONOMIC CLASS: (5,000 TO 9,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'ECONOMIC CLASS: (2,500 TO 4,999 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'ECONOMIC CLASS: (1,000 TO 2,499 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'ECONOMIC CLASS: (LESS THAN 1,000 $) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1111) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1112) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1113) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1114) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1119) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (11191) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (11192) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (11193 & 11194 & 11199) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (112111) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (112112) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (11212) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1122) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1123) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1124) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'NAICS CLASSIFICATION: (1125 & 1129) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)'
#  'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (140 TO 179 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (180 TO 219 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (220 TO 259 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (260 TO 499 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (500 TO 999 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (2,000 OR MORE ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (1,000,000 OR MORE $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (500,000 TO 999,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (250,000 TO 499,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (100,000 TO 249,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (50,000 TO 99,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (25,000 TO 49,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (10,000 TO 24,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (5,000 TO 9,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'ECONOMIC CLASS: (2,500 TO 4,999 $) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1111) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1112) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1113) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1114) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1119) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (11191) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (11192) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (11193 & 11194 & 11199) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (112111) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (112112) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (11212) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1122) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1123) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1124) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'NAICS CLASSIFICATION: (1125 & 1129) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (220 TO 259 ACRES) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'AREA OPERATED: (260 TO 499 ACRES) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'AREA OPERATED: (500 TO 999 ACRES) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'AREA OPERATED: (2,000 OR MORE ACRES) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (1,000,000 OR MORE $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (500,000 TO 999,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (250,000 TO 499,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (100,000 TO 249,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (50,000 TO 99,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (25,000 TO 49,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (10,000 TO 24,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'ECONOMIC CLASS: (5,000 TO 9,999 $) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1111) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1112) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1113) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1114) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1119) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (11191) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (11192) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (11193 & 11194 & 11199) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (112111) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (112112) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (11212) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1122) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1123) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'NAICS CLASSIFICATION: (1125 & 1129) AND AREA HARVESTED: (250 TO 499 ACRES)'
#  'AREA OPERATED: (500 TO 999 ACRES) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'AREA OPERATED: (2,000 OR MORE ACRES) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (1,000,000 OR MORE $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (500,000 TO 999,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (250,000 TO 499,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (100,000 TO 249,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (50,000 TO 99,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'ECONOMIC CLASS: (25,000 TO 49,999 $) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1111) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1112) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1113) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1114) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1119) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (11191) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (11192) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (11193 & 11194 & 11199) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (112111) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (112112) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (11212) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1122) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'NAICS CLASSIFICATION: (1123) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'AREA OPERATED: (70.0 TO 99.9 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)'
#  'AREA OPERATED: (260 TO 499 ACRES) AND AREA HARVESTED: (500 OR MORE ACRES)'
#  'TYPE OF OPERATION: (SMALL INTERIOR)'
#  'TYPE OF OPERATION: (LARGE INTERIOR)' 'ROW WIDTH: (34.6 OR MORE INCHES)'
#  'ROW WIDTH: (38.1 OR MORE INCHES)' 'ROW WIDTH: (38.6 OR MORE INCHES)'
#  'ROW WIDTH: (36.6 TO 38.5 INCHES)' 'ROW WIDTH: (38 INCHES)'
#  'ROW WIDTH: (LESS THAN 20.6 INCHES)' 'ROW WIDTH: (LESS THAN 30.0 INCHES)'
#  'ROW WIDTH: (30 INCHES)' 'ROW WIDTH: (30.6 TO 34.5 INCHES)'
#  'ROW WIDTH: (34.6 TO 36.5 INCHES)' 'ROW WIDTH: (36 INCHES)'
#  'ROW WIDTH: (18.6 TO 28.5 INCHES)' 'ROW WIDTH: (28.6 TO 34.5 INCHES)'
#  'ROW WIDTH: (LESS THAN 10.01 INCHES)' 'ROW WIDTH: (20.6 TO 30.5 INCHES)'
#  'PLANT POPULATION: (27,501 TO 30,000 PLANTS / ACRE)'
#  'PLANT POPULATION: (LESS THAN 20,000 PLANTS / ACRE)'
#  'PLANT POPULATION: (30,001 OR MORE PLANTS / ACRE)'
#  'ROW WIDTH: (10.1 TO 18.5 INCHES)'
#  'BALES GINNED: (7,000 TO 9,999 RUNNING BALES)'
#  'PLANT POPULATION: (22,501 TO 25,000 PLANTS / ACRE)'
#  'PLANT POPULATION: (20,000 TO 22,500 PLANTS / ACRE)'
#  'PLANT POPULATION: (25,001 TO 27,500 PLANTS / ACRE)'
#  'BALES GINNED: (20,000 TO 39,999 RUNNING BALES)'
#  'BALES GINNED: (3,000 TO 4,999 RUNNING BALES)'
#  'BALES GINNED: (40,000 OR MORE RUNNING BALES)'
#  'BALES GINNED: (5,000 TO 6,999 RUNNING BALES)'
#  'BALES GINNED: (10,000 TO 14,999 RUNNING BALES)'
#  'BALES GINNED: (15,000 TO 19,999 RUNNING BALES)'
#  'BALES GINNED: (1 TO 2,999 RUNNING BALES)'
#  'ROW WIDTH: (LESS THAN 7.5 INCHES)' 'ROW WIDTH: (15 INCHES)'
#  'ROW WIDTH: (30 OR MORE INCHES)' 'ROW WIDTH: (7.5 INCHES)'
#  'AREA HARVESTED: (0.1 TO 99.9 ACRES)']
# AGG_LEVEL_DESC : ['COUNTY' 'AGRICULTURAL DISTRICT' 'STATE' 'NATIONAL'
#  'AMERICAN INDIAN RESERVATION' 'WATERSHED' 'REGION : MULTI-STATE'
#  'ZIP CODE']
# STATE_ANSI : [ 8. 10. 20. 30. 31. 35. 38. 40. 46. 48. 56.  1.  4.  5.  6. 12. 13. 22.
#  28. 29. 37. 45. 47. 51. nan 17.  9. 15. 16. 18. 19. 21. 23. 24. 25. 26.
#  27. 33. 34. 36. 39. 41. 42. 44. 49. 50. 53. 54. 55.  2. 32.]
# STATE_FIPS_CODE : [ 8 10 20 30 31 35 38 40 46 48 56  1  4  5  6 12 13 22 28 29 37 45 47 51
#  98 99  0 17  9 15 16 18 19 21 23 24 25 26 27 33 34 36 39 41 42 44 49 50
#  53 54 55  2 32]
# STATE_ALPHA : ['CO' 'DE' 'KS' 'MT' 'NE' 'NM' 'ND' 'OK' 'SD' 'TX' 'WY' 'AL' 'AZ' 'AR'
#  'CA' 'FL' 'GA' 'LA' 'MS' 'MO' 'NC' 'SC' 'TN' 'VA' 'OT' 'US' nan 'IL' 'CT'
#  'HI' 'ID' 'IN' 'IA' 'KY' 'ME' 'MD' 'MA' 'MI' 'MN' 'NH' 'NJ' 'NY' 'OH'
#  'OR' 'PA' 'RI' 'UT' 'VT' 'WA' 'WV' 'WI' 'AK' 'NV']
# STATE_NAME : ['COLORADO' 'DELAWARE' 'KANSAS' 'MONTANA' 'NEBRASKA' 'NEW MEXICO'
#  'NORTH DAKOTA' 'OKLAHOMA' 'SOUTH DAKOTA' 'TEXAS' 'WYOMING' 'ALABAMA'
#  'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'FLORIDA' 'GEORGIA' 'LOUISIANA'
#  'MISSISSIPPI' 'MISSOURI' 'NORTH CAROLINA' 'SOUTH CAROLINA' 'TENNESSEE'
#  'VIRGINIA' 'OTHER STATES' 'US TOTAL' nan 'ILLINOIS' 'CONNECTICUT'
#  'HAWAII' 'IDAHO' 'INDIANA' 'IOWA' 'KENTUCKY' 'MAINE' 'MARYLAND'
#  'MASSACHUSETTS' 'MICHIGAN' 'MINNESOTA' 'NEW HAMPSHIRE' 'NEW JERSEY'
#  'NEW YORK' 'OHIO' 'OREGON' 'PENNSYLVANIA' 'RHODE ISLAND' 'UTAH' 'VERMONT'
#  'WASHINGTON' 'WEST VIRGINIA' 'WISCONSIN' 'ALASKA' 'NEVADA']
# ASD_CODE : [20. 60. 70. 90. 50. 80. 10. 30. 40. 11. 12. 21. 22. 51. 52. 81. 82. 96.
#  97. 98. nan 24. 35. 62. 91.]
# ASD_DESC : ['NORTHEAST' 'EAST CENTRAL' 'SOUTHWEST' 'SOUTHEAST' 'NORTHERN' 'CENTRAL'
#  'SOUTHERN' 'NORTHWEST' 'WEST CENTRAL' 'NORTH CENTRAL' 'SOUTH CENTRAL'
#  'NORTH' 'EAST' 'SOUTH' 'PANHANDLE' 'NORTHERN HIGH PLAINS'
#  'SOUTHERN HIGH PLAINS' 'NORTHERN LOW PLAINS' 'SOUTHERN LOW PLAINS'
#  'CROSS TIMBERS' 'BLACKLANDS' 'EAST TEXAS NORTH' 'EAST TEXAS SOUTH'
#  'TRANS-PECOS' 'EDWARDS PLATEAU' 'COASTAL BEND' 'UPPER COAST'
#  'SOUTH TEXAS' 'LOWER VALLEY' 'WEST' 'OTHER DISTRICTS, ALL COUNTIES' nan
#  'NORTHERN VALLEY' 'MOUNTAINS & EASTERN VALLEY' 'UPPER PLAINS & PIEDMONT'
#  'BLACK BELT' 'COASTAL PLAINS & GULF COAST' 'WIREGRASS'
#  'SACRAMENTO VALLEY' 'SAN JOAQUIN VALLEY' 'SOUTHERN CALIFORNIA'
#  'UPPER DELTA' 'LOWER DELTA' 'SOUTHERN PIEDMONT' 'NORTHERN COASTAL'
#  'CENTRAL COASTAL' 'SOUTHERN COASTAL' 'EASTERN' 'DELTA' 'WEST TENNESSEE'
#  'CENTRAL BASIN' 'SOUTHEASTERN' 'CENTRAL COAST' 'SOUTHEAST AND COASTAL'
#  'NORTHERN MOUNTAIN' 'WESTERN MOUNTAIN' 'NORTHERN PIEDMONT'
#  'CENTRAL PIEDMONT' 'WESTERN RIM' 'CUMBERLAND PLATEAU' 'EAST TENNESSEE'
#  'SOUTHWESTERN' 'NORTHERN COAST' 'SISKIYOU-SHASTA' 'SIERRA MOUNTAINS'
#  'ALL COUNTIES' 'KAUAI AND NIIHAU ISLANDS' 'MAUI, MOLOKAI & LANAI ISLAND'
#  'OAHU ISLAND' 'WEST SOUTHWEST' 'EAST SOUTHEAST' 'PURCHASE' 'MIDWESTERN'
#  'BLUEGRASS' 'EASTERN OR MOUNTAIN' 'WESTERN' 'UPPER EASTERN SHORE'
#  'LOWER EASTERN SHORE' 'UPPER PENINSULA' 'LONG ISLAND' 'NORTHWESTERN'
#  'NORTHEASTERN' 'TANANA VALLEY' 'MATANUSKA-SUSITNA-ANCHORAGE'
#  'NORTHWEST AND MOUNTAIN' 'SAN LUIS VALLEY' 'HAWAII ISLAND']
# COUNTY_ANSI : [ 13.  59.  69.  75.  87. 115. 123.  nan   1.   5.  17.  35.  39.  41.
#  323. 429. 361.  86. 186. 363. 425. 347. 365. 419. 423. 449. 351. 373.
#   90.  20.  14. 343. 379. 459. 499. 405. 457. 443. 435. 465. 403. 455.
#  241.  78. 510.]
# COUNTY_NAME : ['BOULDER' 'JEFFERSON' 'LARIMER' ... 'SKAMANIA' 'DEL NORTE' 'ARLINGTON']
# REGION_DESC : [nan 'SALT RIVER PIMA-MARICOPA' "TOHONO O'ODHAM" 'AK-CHIN'
#  'COLORADO RIVER' 'FORT MOJAVE' 'FORT YUMA-QUECHAN' 'GILA RIVER'
#  'SPEC STATES' 'ANNUAL STATES' 'LAC COURTE OREILLES OJIBWA'
#  'LAKE TRAVERSE' 'LEECH LAKE' 'LOWER BRULE' 'LOWER SIOUX' 'MENOMINEE'
#  'OMAHA' 'ONEIDA TRIBE OF WISCONSIN' 'PINE RIDGE' 'RED LAKE BAND'
#  "ROCKY BOY'S" 'ROSEBUD' 'SAC AND FOX' 'SANTEE SIOUX' 'SPIRIT LAKE'
#  'STANDING ROCK' 'STOCKBRIDGE-MUNSEE'
#  'TURTLE MOUNTAIN/TRENTON INDIAN SERVICE AREA' 'UPPER SIOUX' 'WHITE EARTH'
#  'BLACKFEET' 'CHEYENNE RIVER' 'CROW' 'CROW CREEK' 'FLANDREAU SANTEE'
#  'WINNEBAGO' 'YANKTON' 'FORT BERTHOLD' 'FORT PECK' 'HO-CHUNK'
#  'NAVAJO NATION' 'NEZ PERCE' 'SPOKANE' 'UMATILLA' 'WARM SPRINGS' 'COCOPAH'
#  "COEUR D'ALENE" 'COLVILLE' 'FLATHEAD' 'YAKAMA' 'FORT BELKNAP' 'FORT HALL'
#  'WHEAT, DURUM - ANNUAL STATES' 'WHEAT, SPRING - ANNUAL STATES'
#  'SILAGE ONLY STATES' 'COTTON - SPEC STATES (4 STATE)' 'ILLINOIS' 'IOWA'
#  'NORTH & EAST' 'NORTH CENTRAL' 'SOUTH, WEST, PACIFIC' 'WEST CENTRAL'
#  'SPEC 11-STATE' 'RICE - UNALLOCATED STATES' 'EASTERN STATES'
#  'PUEBLO OF ISLETA' 'BAD RIVER' 'WIND RIVER' 'ID MT OR UT WA' 'CALIFORNIA'
#  'CO OK' 'FL GA SC' 'IA NE' 'ID MT' 'IL IN WI' 'KANSAS' 'KY TN' 'MD VA'
#  'MICHIGAN' 'MINNESOTA' 'MISSOURI' 'NJ NY' 'NORTH CAROLINA' 'NORTH DAKOTA'
#  'OHIO' 'OR UT WA' 'OTHER STATES' 'PENNSYLVANIA' 'TEXAS'
#  'PUEBLO DE COCHITI' 'PUEBLO OF JEMEZ' 'PUEBLO OF SANTO DOMINGO'
#  'PUEBLO OF ZUNI' 'SAN CARLOS APACHE' 'HOPI']
# ZIP_5 : [   nan 35014. 35019. ... 84129. 85121. 85173.]
# WATERSHED_CODE : [       0 18070300 18100100 18100200 18000000 18020100 18030000 18040000
#  18050000 13020200 13030100 13030200 13040100 13040200 13040300 13050000
#  13060000 13070000 13080000 13090000 15000000 15010000 15030100 15030200
#  15040000 15050100 15050200 15050300 15060100 15060200 15070100 15070200
#  'CALIFORNIA, TULARE-BUENA VISTA LAKES' 'CALIFORNIA, SAN JOAQUIN'
#  'CALIFORNIA, SAN FRANCISCO BAY' 'RIO GRANDE, RIO GRANDE-ELEPHANT BUTTE'
#  'RIO GRANDE, RIO GRANDE-CABALLO' 'RIO GRANDE, MINBRES'
#  'RIO GRANDE, RIO GRANDE-FORT QUITMAN' 'RIO GRANDE, RIO GRANDE-AMISTAD'
#  'RIO GRANDE, DEVILS' 'RIO GRANDE, RIO GRANDE CLOSED BASINS'
#  'RIO GRANDE, UPPER PECOS' 'RIO GRANDE, LOWER PECOS'
#  'RIO GRANDE, RIO GRANDE-FALCON' 'RIO GRANDE, LOWER RIO GRANDE'
#  'LOWER COLORADO' 'LOWER COLORADO, LOWER COLORADO-LAKE MEAD'
#  'LOWER COLORADO, LOWER COLORADO' 'LOWER COLORADO, BILL WILLIAMS'
#  'LOWER COLORADO, UPPER GILA' 'LOWER COLORADO, MIDDLE GILA'
#  'LOWER COLORADO, SAN PEDRO-WILLCOX' 'LOWER COLORADO, SANTA CRUZ'
#  'LOWER COLORADO, SALT' 'LOWER COLORADO, VERDE'
#  'LOWER COLORADO, LOWER GILA-AGUA FRIA' 'LOWER COLORADO, LOWER GILA'
#  'LOWER COLORADO, RIO SONOYTA' 'LOWER COLORADO, RIO DE BAVISPE'
#  'ARKANSAS-WHITE-RED, NEOSHO' 'ARKANSAS-WHITE-RED, UPPER CANADIAN'
#  'ARKANSAS-WHITE-RED, MIDDLE CANADIAN'
#  'ARKANSAS-WHITE-RED, LOWER CANADIAN' 'ARKANSAS-WHITE-RED, UPPER BEAVER'
#  'ARKANSAS-WHITE-RED, LOWER BEAVER'
#  'ARKANSAS-WHITE-RED, LOWER NORTH CANADIAN'
#  'ARKANSAS-WHITE-RED, ROBERT S. KERR RESERVOIR'
#  'ARKANSAS-WHITE-RED, LOWER ARKANSAS-FOURCHE LA FAVE'
#  'ARKANSAS-WHITE-RED, PRAIRIE DOG TOWN FORK RED'
#  'ARKANSAS-WHITE-RED, SALT FORK RED' 'ARKANSAS-WHITE-RED, NORTH FORK RED'
#  'ARKANSAS-WHITE-RED, RED-PEASE' 'ARKANSAS-WHITE-RED, RED-LAKE TEXOMA'
#  'ARKANSAS-WHITE-RED, WASHITA' 'ARKANSAS-WHITE-RED, RED-LITTLE'
#  'ARKANSAS-WHITE-RED, RED-SALINE'
#  'ARKANSAS-WHITE-RED, BIG CYPRESS-SULPHUR' 'TEXAS-GULF'
#  'TEXAS-GULF, SABINE' 'TEXAS-GULF, NECHES' 'TEXAS-GULF, UPPER TRINITY'
#  'TEXAS-GULF, LOWER TRINITY' 'TEXAS-GULF, SAN JACINTO'
#  'TEXAS-GULF, GALVESTON BAY-SABINE LAKE' 'TEXAS-GULF, BRAZOS HEADWATERS'
#  'TEXAS-GULF, MIDDLE BRAZOS-CLEAR FORK' 'TEXAS-GULF, MIDDLE BRAZOS-BOSQUE'
#  'TEXAS-GULF, LOWER BRAZOS' 'TEXAS-GULF, LITTLE'
#  'TEXAS-GULF, UPPER COLORADO' 'TEXAS-GULF, MIDDLE COLORADO-CONCHO'
#  'TEXAS-GULF, MIDDLE COLORADO-LLANO' 'TEXAS-GULF, LOWER COLORADO'
#  'TEXAS-GULF, SAN BERNARD COASTAL' 'TEXAS-GULF, LAVACA'
#  'TEXAS-GULF, GUADALUPE' 'TEXAS-GULF, SAN ANTONIO'
#  'TEXAS-GULF, CENTRAL TEXAS COASTAL' 'TEXAS-GULF, NUECES'
#  'TEXAS-GULF, SOUTHWESTERN TEXAS COASTAL' 'RIO GRANDE'
#  'MISSOURI, SMOKY HILL' 'ARKANSAS-WHITE-RED'
#  'ARKANSAS-WHITE-RED, UPPER WHITE' 'ARKANSAS-WHITE-RED, MIDDLE ARKANSAS'
#  'ARKANSAS-WHITE-RED, UPPER CIMARRON' 'ARKANSAS-WHITE-RED, LOWER CIMARRON'
#  'ARKANSAS-WHITE-RED, ARKANSAS-KEYSTONE'
#  'UPPER MISSISSIPPI, UPPER MISSISSIPPI-MERAMEC' 'LOWER MISSISSIPPI'
#  'LOWER MISSISSIPPI, LOWER MISSISSIPPI-MEMPHIS'
#  'LOWER MISSISSIPPI, HATCHIE-OBION'
#  'LOWER MISSISSIPPI, LOWER MISSISSIPPI-HELENA'
#  'LOWER MISSISSIPPI, ST. FRANCIS' 'LOWER MISSISSIPPI, LOWER WHITE'
#  'LOWER MISSISSIPPI, LOWER ARKANSAS'
#  'LOWER MISSISSIPPI, LOWER MISSISSIPPI-GREENVILLE'
#  'LOWER MISSISSIPPI, YAZOO' 'LOWER MISSISSIPPI, UPPER OUACHITA'
#  'LOWER MISSISSIPPI, LOWER OUACHITA' 'LOWER MISSISSIPPI, LOWER RED'
#  'LOWER MISSISSIPPI, BOEUF-TENSAS'
#  'LOWER MISSISSIPPI, LOWER MISSISSIPPI-NATCHEZ'
#  'LOWER MISSISSIPPI, BIG BLACK-HOMOCHITTO'
#  'LOWER MISSISSIPPI, LAKE MAUREPAS' 'LOWER MISSISSIPPI, LOWER GRAND'
#  'LOWER MISSISSIPPI, ATCHAFALAYA-VERMILION'
#  'LOWER MISSISSIPPI, CALCASIEU-MERMENTAU' 'MISSOURI' 'OHIO'
#  'OHIO, KANAWHA' 'OHIO, GREEN' 'OHIO, LOWER CUMBERLAND' 'TENNESSEE'
#  'TENNESSEE, FRENCH BROAD-HOLSTON' 'TENNESSEE, UPPER TENNESSEE'
#  'TENNESSEE, MIDDLE TENNESSEE-ELK' 'TENNESSEE, LOWER TENNESSEE'
#  'UPPER MISSISSIPPI' 'SOUTH ATLANTIC-GULF, TAMPA BAY'
#  'SOUTH ATLANTIC-GULF, AUCILLA-WACCASASSA' 'SOUTH ATLANTIC-GULF, SUWANNEE'
#  'SOUTH ATLANTIC-GULF, OCHLOCKONEE' 'SOUTH ATLANTIC-GULF, APALACHICOLA'
#  'SOUTH ATLANTIC-GULF, FLORIDA PANHANDLE COASTAL'
#  'SOUTH ATLANTIC-GULF, CHOCTAWHATCHEE' 'SOUTH ATLANTIC-GULF, ESCAMBIA'
#  'SOUTH ATLANTIC-GULF, COOSA-TALLAPOOSA' 'SOUTH ATLANTIC-GULF, ALABAMA'
#  '2019-02-11 16:00:08' '2019-02-19 16:00:02' '2020-01-27 16:02:26'
#  '2020-02-03 16:40:09' '2020-02-10 16:00:09' '2020-02-18 16:03:07'
#  '2020-02-24 16:08:30' '2014-12-30 13:37:10' '2020-02-06 09:57:07'
#  '2014-09-23 17:15:16' '2016-05-03 17:51:51' '2014-09-29 16:53:20'
#  '2017-09-14 17:18:56' '2014-05-05 17:11:10' '2020-02-18 16:35:34'
#  '2017-09-08 11:51:12' '2014-08-05 15:44:32' '2015-04-01 14:18:00'
#  '2018-12-10 16:00:08' '2018-12-17 16:00:07' '2017-01-23 16:07:03'
#  '2017-01-17 16:04:29' '2014-08-05 15:51:12' '2014-06-17 16:24:49'
#  '2017-08-01 15:00:29' '2017-11-01 15:00:02' '2018-02-01 15:20:16'
#  '2017-03-01 15:25:20' '2018-03-29 15:52:38' '2016-05-10 13:48:28'
#  '2019-05-13 11:41:31' '2015-10-27 15:23:10' '2016-07-12 13:34:39'
#  '2017-03-10 15:08:33' '2018-03-09 15:15:30' '2019-03-14 15:42:21'
#  '2020-03-12 15:00:10' '2018-05-24 15:21:40']
# VALUE : ['3,500' '6,800' '3,000' ... '1,374,134' '165,865' 913]
# CV_% : [nan '20.6' '32.7' ... '99.0' '95.3' '99.2']

# %%
#area planted, area harvested, yield and production by crop

category = ['AREA PLANTED','AREA HARVESTED','PRODUCTION','YIELD']
filter_crops.STATISTICCAT_DESC.isin(category)

filter_category= filter_crops[filter_crops.STATISTICCAT_DESC.isin(category)]
filter_category.head()
# Out:
#        SOURCE_DESC SECTOR_DESC   GROUP_DESC COMMODITY_DESC   CLASS_DESC  \
# 706737      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706738      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706741      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706742      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706743      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
#
#        PRODN_PRACTICE_DESC         UTIL_PRACTICE_DESC STATISTICCAT_DESC  \
# 706737           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706738           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706741           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706742           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706743           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
#
#        UNIT_DESC                       SHORT_DESC  ...  \
# 706737     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706738     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706741     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706742     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706743     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
#
#                        LOCATION_DESC  YEAR FREQ_DESC  BEGIN_CODE  END_CODE  \
# 706737  COLORADO, NORTHEAST, BOULDER  2002    ANNUAL           0         0
# 706738  COLORADO, NORTHEAST, BOULDER  1997    ANNUAL           0         0
# 706741  COLORADO, NORTHEAST, BOULDER  2010    ANNUAL           0         0
# 706742  COLORADO, NORTHEAST, BOULDER  1995    ANNUAL           0         0
# 706743  COLORADO, NORTHEAST, BOULDER  1996    ANNUAL           0         0
#
#        REFERENCE_PERIOD_DESC WEEK_ENDING            LOAD_TIME  VALUE  CV_%
# 706737                  YEAR         NaN  2012-01-01 00:00:00  3,500   NaN
# 706738                  YEAR         NaN  2012-01-01 00:00:00  6,800   NaN
# 706741                  YEAR         NaN  2015-06-03 15:08:31  3,000   NaN
# 706742                  YEAR         NaN  2012-01-01 00:00:00  7,000   NaN
# 706743                  YEAR         NaN  2012-01-01 00:00:00  7,000   NaN
#
# [5 rows x 39 columns]

# %%
#only county level data

region = ['COUNTY']
filter_category.AGG_LEVEL_DESC.isin(region)

filter_region= filter_category[filter_category.AGG_LEVEL_DESC.isin(region)]
filter_region.head()
# Out:
#        SOURCE_DESC SECTOR_DESC   GROUP_DESC COMMODITY_DESC   CLASS_DESC  \
# 706737      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706738      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706741      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706742      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
# 706743      SURVEY       CROPS  FIELD CROPS           CORN  ALL CLASSES
#
#        PRODN_PRACTICE_DESC         UTIL_PRACTICE_DESC STATISTICCAT_DESC  \
# 706737           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706738           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706741           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706742           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
# 706743           IRRIGATED  ALL UTILIZATION PRACTICES      AREA PLANTED
#
#        UNIT_DESC                       SHORT_DESC  ...  \
# 706737     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706738     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706741     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706742     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
# 706743     ACRES  CORN, IRRIGATED - ACRES PLANTED  ...
#
#                        LOCATION_DESC  YEAR FREQ_DESC  BEGIN_CODE  END_CODE  \
# 706737  COLORADO, NORTHEAST, BOULDER  2002    ANNUAL           0         0
# 706738  COLORADO, NORTHEAST, BOULDER  1997    ANNUAL           0         0
# 706741  COLORADO, NORTHEAST, BOULDER  2010    ANNUAL           0         0
# 706742  COLORADO, NORTHEAST, BOULDER  1995    ANNUAL           0         0
# 706743  COLORADO, NORTHEAST, BOULDER  1996    ANNUAL           0         0
#
#        REFERENCE_PERIOD_DESC WEEK_ENDING            LOAD_TIME  VALUE  CV_%
# 706737                  YEAR         NaN  2012-01-01 00:00:00  3,500   NaN
# 706738                  YEAR         NaN  2012-01-01 00:00:00  6,800   NaN
# 706741                  YEAR         NaN  2015-06-03 15:08:31  3,000   NaN
# 706742                  YEAR         NaN  2012-01-01 00:00:00  7,000   NaN
# 706743                  YEAR         NaN  2012-01-01 00:00:00  7,000   NaN
#
# [5 rows x 39 columns]

# %%
#cleaning specific columns and rows to ensure the count of rows are same
filter_region.shape
# Out:
# (1870368, 39)

# %% [markdown]
# ### Selecting, Dropping, Renaming and Sorting columns from pandas dataframe

# %%
# decision of not considering this column as a part of the dataset
# total row size =1870368
# DOMAINCAT_DESC= "not specified" = 1705838
# 91% of column values are not specified; dropped this column

output = filter_region.drop_duplicates()
output.groupby('DOMAINCAT_DESC').size()
# Out:
# DOMAINCAT_DESC
# AREA HARVESTED: (1,000 OR MORE ACRES)      15792
# AREA HARVESTED: (1.0 TO 24.9 ACRES)        31839
# AREA HARVESTED: (100 TO 249 ACRES)         31513
# AREA HARVESTED: (25.0 TO 99.9 ACRES)       34269
# AREA HARVESTED: (250 TO 499 ACRES)         25483
# AREA HARVESTED: (500 OR MORE ACRES)         5117
# AREA HARVESTED: (500 TO 999 ACRES)         20517
# NOT SPECIFIED                            1705838
# dtype: int64

# %%
watershed = filter_region.drop_duplicates()
watershed.groupby('WATERSHED_DESC').size()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Drop columns
#
# 1. SECTOR_DESC=: single category in column
# 2. GROUP_DESC=: single category in column
# 3. DOMAINCAT_DESC=: 79% of column values are not specified; dropped this column
# 4. STATE_ANSI=: keeping the name of the state for cleaner dataset
# 5. STATE_FIPS_CODE=:keeping the name of the state for cleaner dataset
# 6. STATE_ALPHA=: Keeping the state name only
# 7. CONGR_DISTRICT_CODE=: Nan
# 8. WATERSHED_DESC=: keeping county data, taking column off the dataframe; different geographic location
# 9. WATERSHED_CODE=: keeping county data, taking column off the dataframe; different geographic location
# 10. COUNTRY_CODE=: single category in column
# 11. BEGIN_CODE=: not significant for visualization
# 12. END_CODE=: not significant for visualization
# 13. LOAD_TIME=:  metadata about the dataset
# 14. REFERENCE_PERIOD_DESC
# 15. WEEK_ENDING
# 16. SOURCE_DESC=: aggregating data for both census and survey
# 17. ASD_CODE=:agricultural statistics district, different geographic location, restraining to county
# 18. ZIP_5=: different geographic location

# %%
filter_region=filter_region.drop(columns=['SECTOR_DESC','GROUP_DESC','DOMAINCAT_DESC','STATE_ANSI',
                              'STATE_FIPS_CODE','STATE_ALPHA','CONGR_DISTRICT_CODE','WATERSHED_DESC',
                              'WATERSHED_CODE','COUNTRY_CODE','BEGIN_CODE','END_CODE','LOAD_TIME','REFERENCE_PERIOD_DESC',
                            'WEEK_ENDING','SOURCE_DESC','ASD_CODE','ZIP_5'])

# %%
filter_region.columns
# Out:
# Index(['COMMODITY_DESC', 'CLASS_DESC', 'PRODN_PRACTICE_DESC',
#        'UTIL_PRACTICE_DESC', 'STATISTICCAT_DESC', 'UNIT_DESC', 'SHORT_DESC',
#        'DOMAIN_DESC', 'AGG_LEVEL_DESC', 'STATE_NAME', 'ASD_DESC',
#        'COUNTY_ANSI', 'COUNTY_CODE', 'COUNTY_NAME', 'REGION_DESC',
#        'COUNTRY_NAME', 'LOCATION_DESC', 'YEAR', 'FREQ_DESC', 'VALUE', 'CV_%'],
#       dtype='object')

# %%
# renaming column names
filter_region.rename(columns={'COMMODITY_DESC': 'FIELD_CROPS',
                                'CLASS_DESC': 'CROP_TYPE',
                                'PRODN_PRACTICE_DESC':'PRODN_PRACTICE',
                                'UTIL_PRACTICE_DESC':'UTILIZATION',
                                'STATISTICCAT_DESC':'CATEGORY',
                                'UNIT_DESC':'UNIT',
                                'SHORT_DESC':'ACTIVITY',
                                'DOMAIN_DESC':'DOMAIN',
                                'AGG_LEVEL_DESC':'GEOGRAPHIC_LEVEL',
                                'ASD_DESC':'AGRICULTURAL_DISTT',
                                'FREQ_DESC':'FREQUENCY',
                                'VALUE':'UNIT_VALUE',
                                'CV_%':'CV%'
                                },inplace=True)

# %%
filter_region.columns
# Out:
# Index(['FIELD_CROPS', 'CROP_TYPE', 'PRODN_PRACTICE', 'UTILIZATION', 'CATEGORY',
#        'UNIT', 'ACTIVITY', 'DOMAIN', 'GEOGRAPHIC_LEVEL', 'STATE_NAME',
#        'AGRICULTURAL_DISTT', 'COUNTY_ANSI', 'COUNTY_CODE', 'COUNTY_NAME',
#        'REGION_DESC', 'COUNTRY_NAME', 'LOCATION_DESC', 'YEAR', 'FREQUENCY',
#        'UNIT_VALUE', 'CV%'],
#       dtype='object')

# %% [markdown]
# ### restructure dataframe

# %%
filter_region=filter_region[['YEAR','GEOGRAPHIC_LEVEL','COUNTRY_NAME','STATE_NAME','AGRICULTURAL_DISTT','REGION_DESC','LOCATION_DESC',
                            'COUNTY_ANSI', 'COUNTY_CODE','COUNTY_NAME', 'FIELD_CROPS', 'CROP_TYPE', 'PRODN_PRACTICE', 'UTILIZATION', 'CATEGORY',
                            'ACTIVITY', 'DOMAIN', 'FREQUENCY','UNIT','UNIT_VALUE', 'CV%']]

# %%
#sorted dataframe based on Year values
sorted_data=filter_region.sort_values(['YEAR'])

# %%
sorted_data.shape
# Out:
# (1870368, 21)

# %%
sorted_data.head()
# Out:
#           YEAR GEOGRAPHIC_LEVEL   COUNTRY_NAME    STATE_NAME  \
# 14202660  1990           COUNTY  UNITED STATES  PENNSYLVANIA
# 4895068   1990           COUNTY  UNITED STATES      OKLAHOMA
# 7759973   1990           COUNTY  UNITED STATES         TEXAS
# 4895092   1990           COUNTY  UNITED STATES      OKLAHOMA
# 4895116   1990           COUNTY  UNITED STATES      OKLAHOMA
#
#          AGRICULTURAL_DISTT REGION_DESC                        LOCATION_DESC  \
# 14202660       SOUTHEASTERN         NaN  PENNSYLVANIA, SOUTHEASTERN, LEBANON
# 4895068           SOUTHWEST         NaN           OKLAHOMA, SOUTHWEST, KIOWA
# 7759973    EAST TEXAS NORTH         NaN   TEXAS, EAST TEXAS NORTH, RED RIVER
# 4895092           SOUTHWEST         NaN         OKLAHOMA, SOUTHWEST, TILLMAN
# 4895116       NORTH CENTRAL         NaN     OKLAHOMA, NORTH CENTRAL, ALFALFA
#
#           COUNTY_ANSI  COUNTY_CODE COUNTY_NAME  ...    CROP_TYPE  \
# 14202660         75.0         75.0     LEBANON  ...  ALL CLASSES
# 4895068          75.0         75.0       KIOWA  ...  ALL CLASSES
# 7759973         387.0        387.0   RED RIVER  ...       UPLAND
# 4895092         141.0        141.0     TILLMAN  ...  ALL CLASSES
# 4895116           3.0          3.0     ALFALFA  ...  ALL CLASSES
#
#                           PRODN_PRACTICE                UTILIZATION  \
# 14202660        ALL PRODUCTION PRACTICES                     SILAGE
# 4895068   NON-IRRIGATED, CONTINUOUS CROP  ALL UTILIZATION PRACTICES
# 7759973         ALL PRODUCTION PRACTICES  ALL UTILIZATION PRACTICES
# 4895092   NON-IRRIGATED, CONTINUOUS CROP  ALL UTILIZATION PRACTICES
# 4895116   NON-IRRIGATED, CONTINUOUS CROP  ALL UTILIZATION PRACTICES
#
#                 CATEGORY                                           ACTIVITY  \
# 14202660  AREA HARVESTED                     CORN, SILAGE - ACRES HARVESTED
# 4895068     AREA PLANTED  WHEAT, NON-IRRIGATED, CONTINUOUS CROP - ACRES ...
# 7759973            YIELD      COTTON, UPLAND - YIELD, MEASURED IN LB / ACRE
# 4895092     AREA PLANTED  WHEAT, NON-IRRIGATED, CONTINUOUS CROP - ACRES ...
# 4895116     AREA PLANTED  WHEAT, NON-IRRIGATED, CONTINUOUS CROP - ACRES ...
#
#          DOMAIN FREQUENCY       UNIT UNIT_VALUE  CV%
# 14202660  TOTAL    ANNUAL      ACRES     13,300  NaN
# 4895068   TOTAL    ANNUAL      ACRES    274,500  NaN
# 7759973   TOTAL    ANNUAL  LB / ACRE        381  NaN
# 4895092   TOTAL    ANNUAL      ACRES    173,500  NaN
# 4895116   TOTAL    ANNUAL      ACRES    309,500  NaN
#
# [5 rows x 21 columns]

# %%
sorted_data.tail()
# Out:
#          YEAR GEOGRAPHIC_LEVEL   COUNTRY_NAME      STATE_NAME  \
# 3148966  2019           COUNTY  UNITED STATES         ALABAMA
# 7193164  2019           COUNTY  UNITED STATES  NORTH CAROLINA
# 3149020  2019           COUNTY  UNITED STATES         ALABAMA
# 3148689  2019           COUNTY  UNITED STATES         ALABAMA
# 8141626  2019           COUNTY  UNITED STATES        MARYLAND
#
#                  AGRICULTURAL_DISTT REGION_DESC  \
# 3148966  MOUNTAINS & EASTERN VALLEY         NaN
# 7193164             CENTRAL COASTAL         NaN
# 3149020  MOUNTAINS & EASTERN VALLEY         NaN
# 3148689             NORTHERN VALLEY         NaN
# 8141626         LOWER EASTERN SHORE         NaN
#
#                                          LOCATION_DESC  COUNTY_ANSI  \
# 3148966  ALABAMA, MOUNTAINS & EASTERN VALLEY, CHEROKEE         19.0
# 7193164          NORTH CAROLINA, CENTRAL COASTAL, PITT        147.0
# 3149020   ALABAMA, MOUNTAINS & EASTERN VALLEY, CULLMAN         43.0
# 3148689            ALABAMA, NORTHERN VALLEY, LIMESTONE         83.0
# 8141626        MARYLAND, LOWER EASTERN SHORE, SOMERSET         39.0
#
#          COUNTY_CODE COUNTY_NAME  ...    CROP_TYPE            PRODN_PRACTICE  \
# 3148966         19.0    CHEROKEE  ...  ALL CLASSES  ALL PRODUCTION PRACTICES
# 7193164        147.0        PITT  ...  ALL CLASSES  ALL PRODUCTION PRACTICES
# 3149020         43.0     CULLMAN  ...  ALL CLASSES  ALL PRODUCTION PRACTICES
# 3148689         83.0   LIMESTONE  ...  ALL CLASSES  ALL PRODUCTION PRACTICES
# 8141626         39.0    SOMERSET  ...  ALL CLASSES  ALL PRODUCTION PRACTICES
#
#                        UTILIZATION      CATEGORY  \
# 3148966  ALL UTILIZATION PRACTICES    PRODUCTION
# 7193164  ALL UTILIZATION PRACTICES  AREA PLANTED
# 3149020  ALL UTILIZATION PRACTICES    PRODUCTION
# 3148689  ALL UTILIZATION PRACTICES    PRODUCTION
# 8141626  ALL UTILIZATION PRACTICES         YIELD
#
#                                         ACTIVITY DOMAIN FREQUENCY       UNIT  \
# 3148966    SOYBEANS - PRODUCTION, MEASURED IN BU  TOTAL    ANNUAL         BU
# 7193164                     CORN - ACRES PLANTED  TOTAL    ANNUAL      ACRES
# 3149020    SOYBEANS - PRODUCTION, MEASURED IN BU  TOTAL    ANNUAL         BU
# 3148689    SOYBEANS - PRODUCTION, MEASURED IN BU  TOTAL    ANNUAL         BU
# 8141626  SOYBEANS - YIELD, MEASURED IN BU / ACRE  TOTAL    ANNUAL  BU / ACRE
#
#         UNIT_VALUE  CV%
# 3148966    104,000  NaN
# 7193164     24,000  NaN
# 3149020    362,000  NaN
# 3148689  1,737,000  NaN
# 8141626       45.5  NaN
#
# [5 rows x 21 columns]

# %%
# exporting cleaned data to csv
now = datetime.now()
current_time=now.strftime("%m-%d-%Y,%H-%M-%S")

sorted_data.to_csv('data_exports/cleaned_data'+current_time+'.csv')

# %% [markdown]
# --------- this is the end of the file ----------------
